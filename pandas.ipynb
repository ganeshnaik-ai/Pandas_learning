# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
install pandas
# Out:
#   Cell In[2], line 1
#     install pandas
#             ^
# SyntaxError: invalid syntax

# %%
# !pip install pandas
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().system('pip install pandas')
#
# File /lib/python3.13/site-packages/IPython/core/interactiveshell.py:2620, in InteractiveShell.system_piped(self, cmd)
#    2615     raise OSError("Background processes not supported.")
#    2617 # we explicitly do NOT return the subprocess status code, because
#    2618 # a non-None value would trigger :func:`sys.displayhook` calls.
#    2619 # Instead, we store the exit_code in user_ns.
# -> 2620 self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#
# File /lib/python3.13/site-packages/IPython/utils/_process_emscripten.py:10, in system(cmd)
#       9 def system(cmd):
# ---> 10     raise OSError("Not available")
#
# OSError: Not available

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.2

# %%
# create data frame
df=pd.DataFrame([1,2,3,4],columns=['col_name'])
print(df)
# Out:
#    col_name
# 0         1
# 1         2
# 2         3
# 3         4

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data={
    'name':['ganesh','naik','nikki','mikki','gaike','gowda'],
    'age':[13,34,55,33,32,44],
    'salary':[20000,33000,4500,5000,3444,3443],
    'experiance':[1,2,3,2,1,5]
}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#      name  age  salary  experiance
# 0  ganesh   13   20000           1
# 1    naik   34   33000           2
# 2   nikki   55    4500           3
# 3   mikki   33    5000           2
# 4   gaike   32    3444           1
# 5   gowda   44    3443           5

# %% [markdown]
# ### ***Basic underStanding***

# %%
df.columns
# Out:
# Index(['name', 'age', 'salary', 'experiance'], dtype='object')

# %%
df.shape
# Out:
# (6, 4)

# %%
df.head
# Out:
# <bound method NDFrame.head of      name  age  salary  experiance
# 0  ganesh   13   20000           1
# 1    naik   34   33000           2
# 2   nikki   55    4500           3
# 3   mikki   33    5000           2
# 4   gaike   32    3444           1
# 5   gowda   44    3443           5>

# %%
df.head(3)
# Out:
#      name  age  salary  experiance
# 0  ganesh   13   20000           1
# 1    naik   34   33000           2
# 2   nikki   55    4500           3

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      name  age  salary  experiance
# 0  ganesh   13   20000           1
# 1    naik   34   33000           2
# 2   nikki   55    4500           3
# 3   mikki   33    5000           2
# 4   gaike   32    3444           1
# 5   gowda   44    3443           5>

# %%
df.tail(2)
# Out:
#     name  age  salary  experiance
# 4  gaike   32    3444           1
# 5  gowda   44    3443           5

# %%
print(type(df))
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'dict'>

# %% [markdown]
# #### ***rename()***

# %%
df.rename(columns={'salary':'Monthly-income'})
# Out:
#      name  age  Monthly-income  experiance
# 0  ganesh   13           20000           1
# 1    naik   34           33000           2
# 2   nikki   55            4500           3
# 3   mikki   33            5000           2
# 4   gaike   32            3444           1
# 5   gowda   44            3443           5

# %% [markdown]
# ### ***result shown but not Changed***

# %%
df
# Out:
#      name  age  salary  experiance
# 0  ganesh   13   20000           1
# 1    naik   34   33000           2
# 2   nikki   55    4500           3
# 3   mikki   33    5000           2
# 4   gaike   32    3444           1
# 5   gowda   44    3443           5

# %% [markdown]
# ### **Change in dataFrame use inplace=True default is False**

# %%
df.rename(columns={'salary':'Monthly-income'},inplace=True)

# %%
df
# Out:
#      name  age  Monthly-income  experiance
# 0  ganesh   13           20000           1
# 1    naik   34           33000           2
# 2   nikki   55            4500           3
# 3   mikki   33            5000           2
# 4   gaike   32            3444           1
# 5   gowda   44            3443           5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            6 non-null      object
#  1   age             6 non-null      int64
#  2   Monthly-income  6 non-null      int64
#  3   experiance      6 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 240.0+ bytes

# %%
df.describe()
# Out:
#              age  Monthly-income  experiance
# count   6.000000         6.00000    6.000000
# mean   35.166667     11564.50000    2.333333
# std    13.991664     12292.59471    1.505545
# min    13.000000      3443.00000    1.000000
# 25%    32.250000      3708.00000    1.250000
# 50%    33.500000      4750.00000    2.000000
# 75%    41.500000     16250.00000    2.750000
# max    55.000000     33000.00000    5.000000

# %% [markdown]
# ## **Save and Load Data from csv**

# %%
df.to_csv('Test_data.csv',index=False)

# %%
load_df=pd.read_csv('Test_data.csv')

# %%
load_df
# Out:
#      name  age  Monthly-income  experiance
# 0  ganesh   13           20000           1
# 1    naik   34           33000           2
# 2   nikki   55            4500           3
# 3   mikki   33            5000           2
# 4   gaike   32            3444           1
# 5   gowda   44            3443           5

# %% [markdown]
# ### ***Rows And Columns Slection***

# %%
## Select columns
df[['name']]
df[['name','Monthly-income']]
df.rename(columns={'Monthly-income':'salary'},inplace=True)

# %%
#select rows
#3 loc[df.columns_name=='Value']
df.loc[df.name=='gaike']
# Out:
#     name  age  salary  experiance
# 4  gaike   32    3444           1

# %% [markdown]
# ### loc-with conditions
# ## df.loc[(df.columns_name=='value') & (df.columns_name<=(condition)

# %%
df.loc[(df.name=='naik') & (df.age>=18)]
# Out:
#    name  age  salary  experiance
# 1  naik   34   33000           2

# %%
df.loc[(df.name=='ganesh') & (df.experiance>=0)]
# Out:
#      name  age  salary  experiance
# 0  ganesh   13   20000           1

# %% [markdown]
# ### index based iloc

# %%
## iloc - index-value based
df.iloc[0]
df.iloc[1]
# Out:
# name           naik
# age              34
# salary        33000
# experiance        2
# Name: 1, dtype: object

# %%
df.iloc[1:2]
# Out:
#    name  age  salary  experiance
# 1  naik   34   33000           2

# %%
df.iloc[0:3]
# Out:
#      name  age  salary  experiance
# 0  ganesh   13   20000           1
# 1    naik   34   33000           2
# 2   nikki   55    4500           3

# %%
df.loc[1:2] #[start:stop:step]
# Out:
#     name  age  salary  experiance
# 1   naik   34   33000           2
# 2  nikki   55    4500           3

# %%
df.loc[0:2:2]
# Out:
#      name  age  salary  experiance
# 0  ganesh   13   20000           1
# 2   nikki   55    4500           3

# %% [markdown]
# ### **filter Data-Frame**

# %%
df['age']>18
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# Name: age, dtype: bool

# %%
df['age']>30
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# Name: age, dtype: bool

# %%
df[df['age']>=35]
# Out:
#     name  age  salary  experiance
# 2  nikki   55    4500           3
# 5  gowda   44    3443           5

# %%
df[(df['age']>=20) & (df['salary']>=3500)]
# Out:
#     name  age  salary  experiance
# 1   naik   34   33000           2
# 2  nikki   55    4500           3
# 3  mikki   33    5000           2

# %%
df_age_filter=df[df['age']>=35]
df_age_filter
# Out:
#     name  age  salary  experiance
# 2  nikki   55    4500           3
# 5  gowda   44    3443           5

# %%
df.where(df['age']>=35)
# Out:
#     name   age  salary  experiance
# 0    NaN   NaN     NaN         NaN
# 1    NaN   NaN     NaN         NaN
# 2  nikki  55.0  4500.0         3.0
# 3    NaN   NaN     NaN         NaN
# 4    NaN   NaN     NaN         NaN
# 5  gowda  44.0  3443.0         5.0

# %%
df.where(df['age']>=35 , other='Not Eligible')
# Out:
#            name           age        salary    experiance
# 0  Not Eligible  Not Eligible  Not Eligible  Not Eligible
# 1  Not Eligible  Not Eligible  Not Eligible  Not Eligible
# 2         nikki            55          4500             3
# 3  Not Eligible  Not Eligible  Not Eligible  Not Eligible
# 4  Not Eligible  Not Eligible  Not Eligible  Not Eligible
# 5         gowda            44          3443             5

# %% [markdown]
# #### ***Rows and Columns - Operations (Add, Update, Delete)***

# %%
df
# Out:
#      name  age  salary  experiance
# 0  ganesh   13   20000           1
# 1    naik   34   33000           2
# 2   nikki   55    4500           3
# 3   mikki   33    5000           2
# 4   gaike   32    3444           1
# 5   gowda   44    3443           5

# %%
#3 Add new Columns....
df['Team']=['CEO','HR','CTO','DA','MANAGER','DEAN']

# %%
df
# Out:
#      name  age  salary  experiance     Team
# 0  ganesh   13   20000           1      CEO
# 1    naik   34   33000           2       HR
# 2   nikki   55    4500           3      CTO
# 3   mikki   33    5000           2       DA
# 4   gaike   32    3444           1  MANAGER
# 5   gowda   44    3443           5     DEAN

# %%
## adding new columns by the multiple of anycolumns
df['bonus']=df['salary']*0.2
df
# Out:
#      name  age  salary  experiance     Team   bonus
# 0  ganesh   13   20000           1      CEO  4000.0
# 1    naik   34   33000           2       HR  6600.0
# 2   nikki   55    4500           3      CTO   900.0
# 3   mikki   33    5000           2       DA  1000.0
# 4   gaike   32    3444           1  MANAGER   688.8
# 5   gowda   44    3443           5     DEAN   688.6

# %%
df['increment']=df['bonus']+df['salary']
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0
# 1    naik   34   33000           2       HR  6600.0    39600.0
# 2   nikki   55    4500           3      CTO   900.0     5400.0
# 3   mikki   33    5000           2       DA  1000.0     6000.0
# 4   gaike   32    3444           1  MANAGER   688.8     4132.8
# 5   gowda   44    3443           5     DEAN   688.6     4131.6

# %%
## Addd New Rows
df.loc[len(df)]=['ABC',32,20300,2,'DTO',20300*0.2,20300+20300*0.2]

# %%
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0
# 1    naik   34   33000           2       HR  6600.0    39600.0
# 2   nikki   55    4500           3      CTO   900.0     5400.0
# 3   mikki   33    5000           2       DA  1000.0     6000.0
# 4   gaike   32    3444           1  MANAGER   688.8     4132.8
# 5   gowda   44    3443           5     DEAN   688.6     4131.6
# 6     ABC   32   20300           2      DTO  4060.0    24360.0

# %%
## update value
df.loc[4,'experiance']=4
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0
# 1    naik   34   33000           2       HR  6600.0    39600.0
# 2   nikki   55    4500           3      CTO   900.0     5400.0
# 3   mikki   33    5000           2       DA  1000.0     6000.0
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8
# 5   gowda   44    3443           5     DEAN   688.6     4131.6
# 6     ABC   32   20300           2      DTO  4060.0    24360.0

# %%
## update value - using columns value
df.loc[df.name=='mikki','experiance']=0
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0
# 1    naik   34   33000           2       HR  6600.0    39600.0
# 2   nikki   55    4500           3      CTO   900.0     5400.0
# 3   mikki   33    5000           0       DA  1000.0     6000.0
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8
# 5   gowda   44    3443           5     DEAN   688.6     4131.6
# 6     ABC   32   20300           2      DTO  4060.0    24360.0

# %%
## delete value- rows and columns
df.drop(df[df.name=='ABC'].index) ## drop rows axis=0
# Out:
#      name  age  salary  experiance     Team   bonus  increment
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0
# 1    naik   34   33000           2       HR  6600.0    39600.0
# 2   nikki   55    4500           3      CTO   900.0     5400.0
# 3   mikki   33    5000           0       DA  1000.0     6000.0
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8
# 5   gowda   44    3443           5     DEAN   688.6     4131.6

# %%
df[df.name=='ABC']
# Out:
#   name  age  salary  experiance Team   bonus  increment
# 6  ABC   32   20300           2  DTO  4060.0    24360.0

# %%
## it drop of static on 
## if you wnat df=df.drop('columns_name',
df.drop('increment',axis=1)
# Out:
#      name  age  salary  experiance     Team   bonus
# 0  ganesh   13   20000           1      CEO  4000.0
# 1    naik   34   33000           2       HR  6600.0
# 2   nikki   55    4500           3      CTO   900.0
# 3   mikki   33    5000           0       DA  1000.0
# 4   gaike   32    3444           4  MANAGER   688.8
# 5   gowda   44    3443           5     DEAN   688.6
# 6     ABC   32   20300           2      DTO  4060.0

# %%
df.drop(['bonus','Team'],axis=1) # delete multiple columns
# Out:
#      name  age  salary  experiance  increment
# 0  ganesh   13   20000           1    24000.0
# 1    naik   34   33000           2    39600.0
# 2   nikki   55    4500           3     5400.0
# 3   mikki   33    5000           0     6000.0
# 4   gaike   32    3444           4     4132.8
# 5   gowda   44    3443           5     4131.6
# 6     ABC   32   20300           2    24360.0

# %%
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0
# 1    naik   34   33000           2       HR  6600.0    39600.0
# 2   nikki   55    4500           3      CTO   900.0     5400.0
# 3   mikki   33    5000           0       DA  1000.0     6000.0
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8
# 5   gowda   44    3443           5     DEAN   688.6     4131.6
# 6     ABC   32   20300           2      DTO  4060.0    24360.0

# %% [markdown]
# ### ***Sorting***

# %%
df.sort_values('salary') ### Ascending order
# Out:
#      name  age  salary  experiance     Team   bonus  increment
# 5   gowda   44    3443           5     DEAN   688.6     4131.6
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8
# 2   nikki   55    4500           3      CTO   900.0     5400.0
# 3   mikki   33    5000           0       DA  1000.0     6000.0
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0
# 6     ABC   32   20300           2      DTO  4060.0    24360.0
# 1    naik   34   33000           2       HR  6600.0    39600.0

# %%
df.sort_values('salary',ascending=False) ##3 Descending order
# Out:
#      name  age  salary  experiance     Team   bonus  increment
# 1    naik   34   33000           2       HR  6600.0    39600.0
# 6     ABC   32   20300           2      DTO  4060.0    24360.0
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0
# 3   mikki   33    5000           0       DA  1000.0     6000.0
# 2   nikki   55    4500           3      CTO   900.0     5400.0
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8
# 5   gowda   44    3443           5     DEAN   688.6     4131.6

# %% [markdown]
# ## ***Working with Date Value***

# %%
df['DOJ'] =['2024-01-23','2023-11-03','2025-03-12','2026-05-25','2022-04-29','2023-08-13','2021-9-03']

# %%
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment         DOJ
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0  2024-01-23
# 1    naik   34   33000           2       HR  6600.0    39600.0  2023-11-03
# 2   nikki   55    4500           3      CTO   900.0     5400.0  2025-03-12
# 3   mikki   33    5000           0       DA  1000.0     6000.0  2026-05-25
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8  2022-04-29
# 5   gowda   44    3443           5     DEAN   688.6     4131.6  2023-08-13
# 6     ABC   32   20300           2      DTO  4060.0    24360.0   2021-9-03

# %%
df['DOJ'].dtype
# Out:
# dtype('O')

# %%
df['DOJ']=pd.to_datetime(df['DOJ'])
df['DOJ'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df1=df
df1['lDay']=['23-01-2024','03-11-2023','12-03-2025','25-05-2026','29-04-2022','13-08-2023','03-9-2021']
df1['lDay'].dtype
# Out:
# dtype('O')

# %%
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment        DOJ
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0 2024-01-23
# 1    naik   34   33000           2       HR  6600.0    39600.0 2023-11-03
# 2   nikki   55    4500           3      CTO   900.0     5400.0 2025-03-12
# 3   mikki   33    5000           0       DA  1000.0     6000.0 2026-05-25
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8 2022-04-29
# 5   gowda   44    3443           5     DEAN   688.6     4131.6 2023-08-13
# 6     ABC   32   20300           2      DTO  4060.0    24360.0 2021-09-03

# %%
df1['lDay']=pd.to_datetime(df1['lDay'])
# Out:
# <ipython-input-119-38fa25e872a9>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1['lDay']=pd.to_datetime(df1['lDay'])

# %%
df1['lDay'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df1
# Out:
#      name  age  salary  experiance     Team   bonus  increment        DOJ  \
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0 2024-01-23
# 1    naik   34   33000           2       HR  6600.0    39600.0 2023-11-03
# 2   nikki   55    4500           3      CTO   900.0     5400.0 2025-03-12
# 3   mikki   33    5000           0       DA  1000.0     6000.0 2026-05-25
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8 2022-04-29
# 5   gowda   44    3443           5     DEAN   688.6     4131.6 2023-08-13
# 6     ABC   32   20300           2      DTO  4060.0    24360.0 2021-09-03
#
#         lDay
# 0 2024-01-23
# 1 2023-11-03
# 2 2025-03-12
# 3 2026-05-25
# 4 2022-04-29
# 5 2023-08-13
# 6 2021-09-03

# %%
df.columns
# Out:
# Index(['name', 'age', 'salary', 'experiance', 'Team', 'bonus', 'increment',
#        'DOJ'],
#       dtype='object')

# %%
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment        DOJ
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0 2024-01-23
# 1    naik   34   33000           2       HR  6600.0    39600.0 2023-11-03
# 2   nikki   55    4500           3      CTO   900.0     5400.0 2025-03-12
# 3   mikki   33    5000           0       DA  1000.0     6000.0 2026-05-25
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8 2022-04-29
# 5   gowda   44    3443           5     DEAN   688.6     4131.6 2023-08-13
# 6     ABC   32   20300           2      DTO  4060.0    24360.0 2021-09-03

# %% [markdown]
# ### ***Date Based Operations monthly Comparition***

# %%
## '''extract year month weekly day........
df['DOJ'].dt.year
df['DOJ'].dt.month
df['DOJ'].dt.day
df['DOJ'].dt.day
df['DOJ'].dt.day_name()
# Out:
# 0      Tuesday
# 1       Friday
# 2    Wednesday
# 3       Monday
# 4       Friday
# 5       Sunday
# 6       Friday
# Name: DOJ, dtype: object

# %%
### add a  month columns values
df['month']=df['DOJ'].dt.month
df
df['Year']=df['DOJ'].dt.year
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment        DOJ  \
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0 2024-01-23
# 1    naik   34   33000           2       HR  6600.0    39600.0 2023-11-03
# 2   nikki   55    4500           3      CTO   900.0     5400.0 2025-03-12
# 3   mikki   33    5000           0       DA  1000.0     6000.0 2026-05-25
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8 2022-04-29
# 5   gowda   44    3443           5     DEAN   688.6     4131.6 2023-08-13
# 6     ABC   32   20300           2      DTO  4060.0    24360.0 2021-09-03
#
#    month  Year
# 0      1  2024
# 1     11  2023
# 2      3  2025
# 3      5  2026
# 4      4  2022
# 5      8  2023
# 6      9  2021

# %%
### prohibitation date is + pd.datedelta(days= noof days)
df['DOJ']+pd.Timedelta(days=90)
# Out:
# 0   2024-04-22
# 1   2024-02-01
# 2   2025-06-10
# 3   2026-08-23
# 4   2022-07-28
# 5   2023-11-11
# 6   2021-12-02
# Name: DOJ, dtype: datetime64[ns]

# %% [markdown]
# ### ***Handling Missing values***

# %%
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment        DOJ  \
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0 2024-01-23
# 1    naik   34   33000           2       HR  6600.0    39600.0 2023-11-03
# 2   nikki   55    4500           3      CTO   900.0     5400.0 2025-03-12
# 3   mikki   33    5000           0       DA  1000.0     6000.0 2026-05-25
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8 2022-04-29
# 5   gowda   44    3443           5     DEAN   688.6     4131.6 2023-08-13
# 6     ABC   32   20300           2      DTO  4060.0    24360.0 2021-09-03
#
#    month  Year
# 0      1  2024
# 1     11  2023
# 2      3  2025
# 3      5  2026
# 4      4  2022
# 5      8  2023
# 6      9  2021

# %%
df.isnull()
# Out:
#     name    age  salary  experiance   Team  bonus  increment    DOJ  month  \
# 0  False  False   False       False  False  False      False  False  False
# 1  False  False   False       False  False  False      False  False  False
# 2  False  False   False       False  False  False      False  False  False
# 3  False  False   False       False  False  False      False  False  False
# 4  False  False   False       False  False  False      False  False  False
# 5  False  False   False       False  False  False      False  False  False
# 6  False  False   False       False  False  False      False  False  False
#
#     Year
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
# 5  False
# 6  False

# %%
df
# Out:
#      name  age  salary  experiance     Team   bonus  increment        DOJ  \
# 0  ganesh   13   20000           1      CEO  4000.0    24000.0 2024-01-23
# 1    naik   34   33000           2       HR  6600.0    39600.0 2023-11-03
# 2   nikki   55    4500           3      CTO   900.0     5400.0 2025-03-12
# 3   mikki   33    5000           0       DA  1000.0     6000.0 2026-05-25
# 4   gaike   32    3444           4  MANAGER   688.8     4132.8 2022-04-29
# 5   gowda   44    3443           5     DEAN   688.6     4131.6 2023-08-13
# 6     ABC   32   20300           2      DTO  4060.0    24360.0 2021-09-03
#
#    month  Year
# 0      1  2024
# 1     11  2023
# 2      3  2025
# 3      5  2026
# 4      4  2022
# 5      8  2023
# 6      9  2021

# %%
import numpy as np
df.loc[df.name=='nikki','salary']=np.nan

# %%
df.loc[df.name=='gowda','salary']=np.nan

# %%
df
# Out:
#      name  age   salary  experiance     Team   bonus  increment        DOJ  \
# 0  ganesh   13  20000.0           1      CEO  4000.0    24000.0 2024-01-23
# 1    naik   34  33000.0           2       HR  6600.0    39600.0 2023-11-03
# 2   nikki   55      NaN           3      CTO   900.0     5400.0 2025-03-12
# 3   mikki   33   5000.0           0       DA  1000.0     6000.0 2026-05-25
# 4   gaike   32   3444.0           4  MANAGER   688.8     4132.8 2022-04-29
# 5   gowda   44      NaN           5     DEAN   688.6     4131.6 2023-08-13
# 6     ABC   32  20300.0           2      DTO  4060.0    24360.0 2021-09-03
#
#    month  Year
# 0      1  2024
# 1     11  2023
# 2      3  2025
# 3      5  2026
# 4      4  2022
# 5      8  2023
# 6      9  2021

# %%
df.isnull()
# Out:
#     name    age  salary  experiance   Team  bonus  increment    DOJ  month  \
# 0  False  False   False       False  False  False      False  False  False
# 1  False  False   False       False  False  False      False  False  False
# 2  False  False    True       False  False  False      False  False  False
# 3  False  False   False       False  False  False      False  False  False
# 4  False  False   False       False  False  False      False  False  False
# 5  False  False    True       False  False  False      False  False  False
# 6  False  False   False       False  False  False      False  False  False
#
#     Year
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
# 5  False
# 6  False

# %%
df.describe()
# Out:
#              age       salary  experiance        bonus     increment  \
# count   7.000000      5.00000    7.000000     7.000000      7.000000
# mean   34.714286  16348.80000    2.428571  2562.485714  15374.914286
# min    13.000000   3444.00000    0.000000   688.600000   4131.600000
# 25%    32.000000   5000.00000    1.500000   794.400000   4766.400000
# 50%    33.000000  20000.00000    2.000000  1000.000000   6000.000000
# 75%    39.000000  20300.00000    3.500000  4030.000000  24180.000000
# max    55.000000  33000.00000    5.000000  6600.000000  39600.000000
# std    12.828540  12263.10349    1.718249  2339.440252  14036.641510
#
#                        DOJ      month         Year
# count                    7   7.000000     7.000000
# mean   2023-11-15 00:00:00   5.857143  2023.428571
# min    2021-09-03 00:00:00   1.000000  2021.000000
# 25%    2022-12-20 12:00:00   3.500000  2022.500000
# 50%    2023-11-03 00:00:00   5.000000  2023.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        7 non-null      object
#  1   age         7 non-null      int64
#  2   salary      5 non-null      float64
#  3   experiance  7 non-null      int64
#  4   Team        7 non-null      object
#  5   bonus       7 non-null      float64
#  6   increment   7 non-null      float64
#  7   DOJ         7 non-null      datetime64[ns]
#  8   month       7 non-null      int32
#  9   Year        7 non-null      int32
# dtypes: datetime64[ns](1), float64(3), int32(2), int64(2), object(2)
# memory usage: 728.0+ bytes

# %%
df.isnull().sum()
# Out:
# name          0
# age           0
# salary        2
# experiance    0
# Team          0
# bonus         0
# increment     0
# DOJ           0
# month         0
# Year          0
# dtype: int64

# %%
df.fillna(0)
# Out:
#      name  age   salary  experiance     Team   bonus  increment        DOJ  \
# 0  ganesh   13  20000.0           1      CEO  4000.0    24000.0 2024-01-23
# 1    naik   34  33000.0           2       HR  6600.0    39600.0 2023-11-03
# 2   nikki   55      0.0           3      CTO   900.0     5400.0 2025-03-12
# 3   mikki   33   5000.0           0       DA  1000.0     6000.0 2026-05-25
# 4   gaike   32   3444.0           4  MANAGER   688.8     4132.8 2022-04-29
# 5   gowda   44      0.0           5     DEAN   688.6     4131.6 2023-08-13
# 6     ABC   32  20300.0           2      DTO  4060.0    24360.0 2021-09-03
#
#    month  Year
# 0      1  2024
# 1     11  2023
# 2      3  2025
# 3      5  2026
# 4      4  2022
# 5      8  2023
# 6      9  2021

# %%
df.fillna(df['salary'].mean())
# Out:
#      name  age   salary  experiance     Team   bonus  increment        DOJ  \
# 0  ganesh   13  20000.0           1      CEO  4000.0    24000.0 2024-01-23
# 1    naik   34  33000.0           2       HR  6600.0    39600.0 2023-11-03
# 2   nikki   55  16348.8           3      CTO   900.0     5400.0 2025-03-12
# 3   mikki   33   5000.0           0       DA  1000.0     6000.0 2026-05-25
# 4   gaike   32   3444.0           4  MANAGER   688.8     4132.8 2022-04-29
# 5   gowda   44  16348.8           5     DEAN   688.6     4131.6 2023-08-13
# 6     ABC   32  20300.0           2      DTO  4060.0    24360.0 2021-09-03
#
#    month  Year
# 0      1  2024
# 1     11  2023
# 2      3  2025
# 3      5  2026
# 4      4  2022
# 5      8  2023
# 6      9  2021
